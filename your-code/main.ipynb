# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def uniform_random_values(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %%
# your code here
result_1 = uniform_random_values(10,15,100)
result_2 = uniform_random_values(10,60,1000)

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(1, 2)

# Dibujar en el primer subplot
ax1.hist(result_1, alpha=0.5, label='result1', bins=10)
ax1.set_title('Histograma de result1')
ax1.legend()

# Dibujar en el segundo subplot
ax2.hist(result_2, alpha=0.5, label='result2', bins=10)
ax2.set_title('Histograma de result2')
ax2.legend()

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
print("En el segundo resultado al tener más capacidad, da lugar a mayor uniformidad en la forma del histograma")
# Out:
# En el segundo resultado al tener más capacidad, da lugar a mayor uniformidad en la forma del histograma

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
norm_result_1 = norm.rvs(loc=10, scale=1, size=1000)

# %%
# your code here
norm_result_2 = norm.rvs(loc=10, scale=50, size=1000)

# %%
# your code here
fig_norm, (ax1_norm, ax2_norm) = plt.subplots(1, 2)

# Dibujar en el primer subplot
ax1_norm.hist(norm_result_1, alpha=0.5, bins=50)
ax1_norm.legend()

# Dibujar en el segundo subplot
ax2_norm.hist(norm_result_2, alpha=0.5, bins=50)
ax2_norm.legend()

plt.show()
# Out:
# C:\Users\Javier\AppData\Local\Temp\ipykernel_6796\1065252113.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1_norm.legend()
# C:\Users\Javier\AppData\Local\Temp\ipykernel_6796\1065252113.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2_norm.legend()

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Son bastante parecidas, pero el segundo resultado al tener una desviación estándar mayor es menos uniforme y tiene más picos

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
df = pd.read_csv("vehicles.csv")
display(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
plt.hist(df["Fuel Barrels/Year"], bins=50,density=True, 
         color='steelblue', edgecolor='black')

plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.hist(df["CO2 Emission Grams/Mile"], bins=50,density=True, alpha=0.7, 
         color='steelblue', edgecolor='black')

plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.hist(df["Combined MPG"], bins=50,density=True, alpha=0.7, 
         color='steelblue', edgecolor='black')

plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [raw]
# Fuel Barrels/Year por la forma normal de la distribución. Quiere decir que el consumo de barriles por vehículo coinciden la media, moda y mediana

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def exponential_distributed_mean_10(size):
    return np.random.exponential(10, size)
    
exponential_data_1 = exponential_distributed_mean_10(10)
exponential_data_2 = exponential_distributed_mean_10(100)

# your code here
fig_exp, (ax1_exp, ax2_exp) = plt.subplots(1, 2)

# Dibujar en el primer subplot
ax1_exp.hist(exponential_data_1, bins=100)
ax1_exp.legend()

# Dibujar en el segundo subplot
ax2_exp.hist(exponential_data_2, bins=100)
ax2_exp.legend()

plt.show()
# Out:
# C:\Users\Javier\AppData\Local\Temp\ipykernel_6796\1085040987.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1_exp.legend()
# C:\Users\Javier\AppData\Local\Temp\ipykernel_6796\1085040987.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2_exp.legend()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here
import math

lambd = 1/10
x = 15

prob = 1 - math.exp(-lambd * x)
print(f"The probability is: {prob:.4f}")
# Out:
# The probability is: 0.7769

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here
# p(x > 15)
prob = math.exp(-lambd * x)
print(f"The probability is: {prob:.4f}")
# Out:
# The probability is: 0.2231
